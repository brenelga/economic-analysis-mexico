# %% [markdown]
# # Análisis Exploratorio de Datos
# ## Indicadores macroeconómicos de México
#
# **Versión**: 1.0
#
# **Fecha**: 2026-02-17
#
# **Autor**: TSU. Jesús Brenel Galicia Aguilar
#
# **Estado**: Borrador

# %% [markdown]
# ### Control de Cambios
# | Fecha | Version | Comentarios |
# | --- | --- | --- |
# | 2026-02-17 | 0.1 | Creación del notebook |
